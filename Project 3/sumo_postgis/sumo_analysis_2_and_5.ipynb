# %% [markdown]
# # Analiza podataka dobijenih simulacijom u SUMO-GUI okruzenju
# ## Import svih potrebnih biblioteka za analizu

# %%
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine

import movingpandas as mpd
from shapely.geometry import Point
import folium
import numpy as np
# Out:
# C:\D\GIS\GIS-GIT\GIS-GIT\Project 3\sumo_postgis\venv\Lib\site-packages\movingpandas\__init__.py:41: UserWarning: Missing optional dependencies. To use the trajectory smoother classes please install Stone Soup (see https://stonesoup.readthedocs.io/en/latest/#installation).
#   warnings.warn(e.msg, UserWarning)

# %% [markdown]
# ## Uspostavljanje konekcije sa PostGIS bazom podataka

# %%
engine = create_engine("postgresql://postgres:password@localhost:5432/sumo_db")

# %% [markdown]
# ## Uzimanje podataka ( vozila ) iz PostGIS baze podataka

# %%
fcd = gpd.read_postgis(
    """
    SELECT *
    FROM fcd_tracks
    """,
    engine,
    geom_col="geom"
)

#ovo sam napisao jer sam greskom oznacio geom podatke u POSTGIS pri importovanju podataka da su EPSG:3857
#umesto EPSG:4326 pa ispravljam gresku naknadno, plus konvertujem u EPSG:3857 jer je bolje za analizu u ovom slucaju
fcd = fcd.set_crs(4326, allow_override=True).to_crs(3857)

#ispravljaju se i x/y kolone tako da budu u ispravnom koodrinatnom sistemu
fcd["x"] = fcd.geometry.x
fcd["y"] = fcd.geometry.y

print("FCD shape:", fcd.shape)
print("\nKolone:", fcd.columns)
print("\nPrvih 5 redova:")
display(fcd.head())
# Out:
# FCD shape: (1756660, 11)
#
# Kolone: Index(['vehicle_id', 'time', 'x', 'y', 'angle', 'type', 'speed', 'pos', 'lane',
#        'slope', 'geom'],
#       dtype='str')
#
# Prvih 5 redova:
#     vehicle_id  time              x             y   angle  \
# 0         bus0   0.0  478648.986165  6.816522e+06  335.41
# 1  motorcycle0   0.0  479878.509940  6.817127e+06  153.28
# 2       truck0   0.0  479328.146378  6.817549e+06  130.27
# 3         veh0   0.0  479826.746377  6.816928e+06  330.37
# 4         bus0   1.0  478642.529634  6.816533e+06  330.31
#
#                     type  speed    pos            lane  slope  \
# 0                bus_bus   8.33  12.10       7493814_0    0.0
# 1  motorcycle_motorcycle  13.89   2.30  -200026251#2_0    0.0
# 2            truck_truck   8.46   7.20      -7475252_0    0.0
# 3          veh_passenger  13.89   5.10     7477284#0_0    0.0
# 4                bus_bus   8.22  20.32       7493814_0    0.0
#
#                              geom
# 0  POINT (478648.986 6816521.529)
# 1   POINT (479878.51 6817127.054)
# 2  POINT (479328.146 6817549.246)
# 3  POINT (479826.746 6816927.925)
# 4   POINT (478642.53 6816533.306)

# %% [markdown]
# ## konverzija formata vremena iz sekundi u datetime, jer movingpandas radi sa datetime formatom

# %%
import datetime

base_time = pd.Timestamp("2026-01-01")

fcd["t"] = base_time + pd.to_timedelta(fcd["time"], unit="s")

#sada svi vremenski podaci su konvertovani iz sekunda u 2026-01-01 + offset (tj broj sekunda).

print("primer vremenske kolone:")
display(fcd[["time", "t"]].head())

print("Vremenski opseg:")
print(fcd["t"].min(), "→", fcd["t"].max())
# Out:
# primer vremenske kolone:
#    time                   t
# 0   0.0 2026-01-01 00:00:00
# 1   0.0 2026-01-01 00:00:00
# 2   0.0 2026-01-01 00:00:00
# 3   0.0 2026-01-01 00:00:00
# 4   1.0 2026-01-01 00:00:01
# Vremenski opseg:
# 2026-01-01 00:00:00 → 2026-01-01 00:59:59

# %% [markdown]
# # Analiza 2 i 5: Prosečna brzina vozila po ulicama u određenom vremenskom periodu

# %% [markdown]
# ## druga analiza je veoma slična prvoj analizi s tim što se u ovom slučaju gleda prosečna brzina vozila a ne broj vozila u ulici

# %%
import branca.colormap as cm
from shapely.geometry import LineString

# %% [markdown]
# ## postavljanje vremenskog intervala za koji se vrši analiza

# %%
start_time = pd.Timestamp("2026-01-01 00:00:00")
end_time = pd.Timestamp("2026-01-01 01:00:00")

print("ukupna kolicina podataka:", len(fcd))
print("vremenski opseg:", fcd["t"].min(), "→", fcd["t"].max())
print()
# Out:
# ukupna kolicina podataka: 1756660
# vremenski opseg: 2026-01-01 00:00:00 → 2026-01-01 00:59:59

# %%
#filtriranje fcd podataka tako da samo ostanu podaci koji su u traženom vremenskom periodu
period = fcd[
    (fcd["t"] >= start_time) &
    (fcd["t"] <= end_time)
].copy()

print("filtrirani podaci:", len(period))
print("vozila:", period["vehicle_id"].nunique())
print()
# Out:
# filtrirani podaci: 1756660
# vozila: 2375

# %%
# pravljenje liste statistike tako što se filtrirani podaci iz fcd grupišu po lane-u, uzimaju se brzine iz zabeležene u tom lane-u
# zatim se računa prosek i dobija se novi DataFrame gde imamo dve kolone lane i avg_speed
speed_stats = (
    period.groupby("lane")["speed"]
    .mean()
    .reset_index(name="avg_speed")
)

print("top 10 lane-ova po prosečnoj brzini:")
print(speed_stats.sort_values("avg_speed", ascending=False).head(10))
print()

print("top 10 najsporijih lane-ova:")
print(speed_stats.sort_values("avg_speed").head(10))
print()
# Out:
# top 10 lane-ova po prosečnoj brzini:
#                                     lane  avg_speed
# 149                       1505707610#0_1  16.600000
# 147                         1505510651_1  14.718276
# 437                     :13773430500_0_1  14.500000
# 214                          444314259_1  14.448333
# 879                        :45222550_1_1  14.280000
# 1120   :cluster_413394652_8551649496_6_0  14.216429
# 424                      :1165729396_0_0  14.120000
# 1012  :cluster_1165729110_1165729566_1_1  14.087647
# 365                          837553903_0  14.035000
# 100                        100876531#0_1  13.985161
#
# top 10 najsporijih lane-ova:
#                                                    lane  avg_speed
# 220                                         461164969_1   0.000000
# 398                                     :1165729136_3_0   0.015231
# 871                                       :45221351_1_0   0.023669
# 1131                     :cluster_45211629_45212465_5_0   0.024206
# 327                                         7477236#1_1   0.036931
# 162                                        1521892286_0   0.043364
# 52                                           -7477131_0   0.049033
# 835                                      :45219439_10_0   0.052750
# 803                                       :45216491_5_0   0.055769
# 951   :cluster_1164135846_1164135877_1164135881_1164...   0.061252

# %%
# kao i u prethodnom primeru formiraju se linestring-ovi tako što uzmemo filtrirane fcd podatke, sortiramo po vremenu 
# grupišemo po lane-u, konstruišemo listu parova koordinata za lane, konstruišemo linestring i dodajemo listi
# i na kraju od liste linestring-ova konstruišemo GeoDataFrame

# podaci se sortiraju po vremenu kako bi tačke u LineString-u pratile redosled kretanja
period_sorted = period.sort_values("t")

lane_lines = []

for lane, group in period_sorted.groupby("lane"):

    coords = list(zip(group["x"], group["y"]))

    # radi bržeg prikaza i manje memorijske potrošnje zadržava se svaka treća tačka
    coords = coords[::3]

    # uklanjaju se duplikati koordinata kako bi se izbegle nepotrebne tačke u geometriji
    coords = list(dict.fromkeys(coords))
    
    if len(coords) < 2:
        continue

    lane_lines.append({
        "lane": lane,
        "geometry": LineString(coords)
    })

lane_gdf = gpd.GeoDataFrame(
    lane_lines,
    geometry="geometry",
    crs="EPSG:3857"
)

# %%
# geometrije lane-ova spajaju se sa tabelom prosečnih brzina koristeći kolonu "lane"
result = lane_gdf.merge(speed_stats, on="lane")

# zadržava se 60 lane-ova sa najvećom prosečnom brzinom radi preglednije vizuelizacije
result = result.sort_values("avg_speed", ascending=False).head(60)

print("Lane-ovi posle filtriranja:", len(result))
# Out:
# Lane-ovi posle filtriranja: 60

# %%
print("geometrije:")
print(result.geometry.geom_type.value_counts())
print()

print("statistika o brzinama:")
print(result["avg_speed"].describe())
print()

# sanity check da se ne bi pojavile neke čudne brzine
print("min pros. brzina posle filtriranja:", result["avg_speed"].min())
print("max pros. brzina posle filtriranja:", result["avg_speed"].max())
print()
# Out:
# geometrije:
# LineString    60
# Name: count, dtype: int64
#
# statistika o brzinama:
# count    60.000000
# mean     13.243887
# std       0.498145
# min      12.620857
# 25%      12.850314
# 50%      13.074321
# 75%      13.533328
# max      14.718276
# Name: avg_speed, dtype: float64
#
# min pros. brzina posle filtriranja: 12.620857142857144
# max pros. brzina posle filtriranja: 14.718275862068966

# %%
print("broj lane-ova:", len(result))

print(result.geometry.apply(lambda g: len(g.coords)).describe())

print("Maksimalan broj tačaka u jednom LineString-u:")
print(result.geometry.apply(lambda g: len(g.coords)).max())
# Out:
# broj lane-ova: 60
# count     60.000000
# mean      42.833333
# std       90.788480
# min        2.000000
# 25%        6.000000
# 50%       13.500000
# 75%       35.750000
# max      581.000000
# Name: geometry, dtype: float64
# Maksimalan broj tačaka u jednom LineString-u:
# 581

# %%
# na kraju na potpuno istovetan način kao i sa prošlom analizom kreiramo folium mapu.

# geometrije se uprošćavaju kako bi renderovanje mape bilo brže
result["geometry"] = result["geometry"].simplify(2)

result = result.to_crs(4326)

center_geom = result.geometry.union_all().centroid
center = [center_geom.y, center_geom.x]

m = folium.Map(
    location=center,
    zoom_start=13,
    tiles="CartoDB positron"
)

# DISCRETE colormap-a
colormap = cm.LinearColormap(
    colors=[
        "#FFD580",  # svetlonarandžasta
        "#FFA500",  # narandžasta
        "#FF6A00",  # tamnonarandžasta
        "#FF0000"   # crvena
    ],
    vmin=result["avg_speed"].min(),
    vmax=result["avg_speed"].max()
)

for row in result.itertuples():

    coords = [(y, x) for x, y in row.geometry.coords]

    folium.PolyLine(
        locations=coords,
        color=colormap(row.avg_speed),
        weight=4,
        opacity=0.85,
        tooltip=f"{row.lane} | {row.avg_speed:.2f} m/s"
    ).add_to(m)

colormap.caption = "Average Speed (m/s)"
colormap.add_to(m)


print("lane-ovi:", len(result))
print("prosečne brzine (min/max):", result["avg_speed"].min(), result["avg_speed"].max())

m
# Out:
# lane-ovi: 60
# prosečne brzine (min/max): 12.620857142857144 14.718275862068966
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6939d5fe24317246d16ec092c579eb2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6939d5fe24317246d16ec092c579eb2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6939d5fe24317246d16ec092c579eb2c = L.map(
#                 &quot;map_6939d5fe24317246d16ec092c579eb2c&quot;,
#                 {
#                     center: [52.09270521259702, 4.304006371978201],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ac393c7aec4bbd0638b05887659947e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ac393c7aec4bbd0638b05887659947e.addTo(map_6939d5fe24317246d16ec092c579eb2c);
#
#
#             var poly_line_585e4b81ae73b2535fc2e30757dc4a41 = L.polyline(
#                 [[52.095424999999985, 4.308071], [52.096208999999995, 4.307378], [52.095486, 4.308017999999999], [52.09582599999999, 4.307719]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.85, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_6939d5fe24317246d16ec092c579eb2c);
#
#
#             poly_line_585e4b81ae73b2535fc2e30757dc4a41.bindTooltip(
#                 `&lt;div&gt;
#                      1505510651_1 | 14.72 m/s
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_75e8d6da2d2895c44dc41c0b780fb5c4 = L.polyline(
#                 [[52.095315, 4.308114999999999], [52.095286, 4.30814]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff2900ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff2900ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.85, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_6939d5fe24317246d16ec092c579eb2c);
#
#
#             poly_line_75e8d6da2d2895c44dc41c0b780fb5c4.bindTooltip(
#                 `&lt;div&gt;
#                      444314259_1 | 14.45 m/s
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_df0cf3e91e3b2cfdb26a1c1329a60cfd = L.polyline(
#                 [[52.09521300000001, 4.308204], [52.09515199999999, 4.308257]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff4200ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff4200ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.85, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4}
#             ).addTo(map_6939d5fe24317246d16ec092c579eb2c);
#
#
#             poly_line_df0cf3e91e3b2cfdb26a1c1329a60cfd.bindTooltip(
#                 `&lt;div&gt;
#                      :45222550_1_1 | 14.28 m/s
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_7398a84079f0f72432cd8bbcb3eb889f = L.polyline(
#                 [[52.095088, 4.300508], [52.094942, 4.300522], [52.095074, 4.30051]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff4c00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff4c00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.85, &quot;sm
